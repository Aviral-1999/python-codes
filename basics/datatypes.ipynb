# %% [markdown]
# Python has 9 basic datatypes
# -int
# -float
# -bool -> True,False
# -Nonetype -> None
# -str
# -list
# -tuple
# -set
# -dict

# %%
a = 319564
b = -524664

# %%
int(123.123)
# Out:
# 123

# %%
ord("a")
# Out:
# 97

# %%
int(False)
# Out:
# 0

# %%
a = 1.25
b = -0.215455

# %%
print (type(a),type(b))
# Out:
# <class 'float'> <class 'float'>

# %%
a = "Hello"
b = 'Hello'

# %%
print(type(a),type(b))
# Out:
# <class 'str'> <class 'str'>

# %%
str(1.22546556)
# Out:
# '1.22546556'

# %%
a = True
b = False
print(type(a),type(b))
# Out:
# <class 'bool'> <class 'bool'>

# %%
a = None 
b = None 
print(type(a), type(b))
# Out:
#   File "C:\Users\2016\AppData\Local\Temp/ipykernel_5640/2683813729.py", line 3
#     print(type(a),'\n' type(b))
#                        ^
# SyntaxError: invalid syntax

# %%
a = [12,15,50,20]
b = [20,50,80]
print(type(a),type(b))
# Out:
# <class 'list'> <class 'list'>

# %%
a = (12,15,40)
b = (15,80,70)
print(type(a),type(b))
# Out:
# <class 'tuple'> <class 'tuple'>

# %%
a= {15,15,20}
b= {15,80,70}
print(type(a),type(b))
# Out:
# <class 'set'> <class 'set'>

# %%
a = {'a': "apple", 'b': "banana"}
print(type(a))
# Out:
# <class 'dict'>
