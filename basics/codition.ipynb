# %% [markdown]
# #condition in python
# -if
# -if else
# -if else if
# **code Block**
# a code block is a piece of code that will do something on python
# if start with a : and follow indentation quidelines provided by
# pep8

# %%
a = int(input("inter a number"))
if a>10:
    print("wah wah")
print(a)
# Out:
# wah wah
# 15

# %% [markdown]
# WAP of find out if a number is even or odd

# %%
num = int(input("inter a number"))
if num % 2==0 :
  print("number is even")
else :
  print("number is odd")
# Out:
# number is odd
