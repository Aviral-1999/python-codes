# %% [markdown]
# #Operator in python
# -math operator
# -conditional operator
# -logical operator (and or not)
# -assignment operator
# -membership operator (in)
# -bitwise operator
# -instance operator (is)

# %%
10+3
# Out:
# 13

# %%
10*3
# Out:
# 30

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3 #whole value
# Out:
# 3

# %%
2**2 #exponant
# Out:
# 4

# %%
10>3
# Out:
# True

# %%
10<3
# Out:
# False

# %%
10>=3
# Out:
# True

# %%
2 > 3 and 5 > 3
# Out:
# False

# %%
100==5 or 5==5
# Out:
# True

# %%
not 1>0
# Out:
# False

# %%
a=100 #asignment operator
b=5

# %%
a+=100 #a=a+100

# %%
a
# Out:
# 300

# %%
a
# Out:
# 300

# %%
movies = ['free GUy', 'mimi']

# %%
'mimi' in movies
# Out:
# True

# %%
movies
# Out:
# ['free GUy', 'mimi']
