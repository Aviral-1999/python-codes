# %%
input()
# Out:
# 'wow'

# %%
month = input()

# %%
name = input ("Who are you ?")
city = input ("where do you Live")

# %%
a = int(input('Fav number batao!'))
b = int(input("non fav number batao!"))

# %%
name = (input('your name'))
age = int(input('inter your age'))
Collage = (input('inter your collage'))
Semester = (input('inter your semester detail'))

# %%
a = int(input('inter a number'))
b = int(input('input second number'))
c = int(input('inter third number'))
Multiply = a*b*c
print (Multiply)
# Out:
# 1320

# %%
print(name,city,month, sep='_')
# Out:
# Aviral_kanpur_ss

# %%
print('name=>', name)
print('city=>',city)
# Out:
# name=> Aviral
# city=> kanpur

# %% [markdown]
# 24/oct/2021

# %%
weather = input('how the weather ?')
time = input('whats the time ')

# %% [markdown]
# Output format style
# -comma seperated style
# -format specifier
# -concatenation
# -format function
# -f string(v.3.6)

# %%
print('the weather is', weather, '\n' 'and the time is ' , time)
# Out:
# the weather is cold
# and the time is  3pm

# %%
print("the weather is %s and the time is %s"%(weather,time))
# Out:
# the weather is cold and the time is 3pm

# %%
print("the weather is "+weather+ " and the time is "+time) #nhi use kerna hai
# Out:
# the weather is cold and the time is 3pm

# %%
print("the weather is {} and the time is {}" .format(weather ,time)) # ye acha tarika hai
# Out:
# the weather is cold and the time is 3pm

# %%
print(f"the weather is {weather} and \n the time is {time}") #yahi use kerna hai sabse best tarika
# Out:
# the weather is cold and
#  the time is 3pm
